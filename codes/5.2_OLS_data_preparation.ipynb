# %%
import pandas as pd
import numpy as np

# %%
OAK311_categories_count_CB_2015 = pd.read_csv('../Data/311_Oakland/Oakland311_2015_pivotTable.csv')
OAK311_categories_count_CB_2015 = OAK311_categories_count_CB_2015.iloc[:,1:]
OAK311_categories_count_CB_2015['GEOID10'] = OAK311_categories_count_CB_2015['GEOID10'].astype(str)

OAK311_categories_count_CB_2016 = pd.read_csv('../Data/311_Oakland/Oakland311_2016_pivotTable.csv')
OAK311_categories_count_CB_2016 = OAK311_categories_count_CB_2016.iloc[:,1:]
OAK311_categories_count_CB_2016['GEOID10'] = OAK311_categories_count_CB_2016['GEOID10'].astype(str)

OAK311_categories_count_CB_2017 = pd.read_csv('../Data/311_Oakland/Oakland311_2017_pivotTable.csv')
OAK311_categories_count_CB_2017 = OAK311_categories_count_CB_2017.iloc[:,1:]
OAK311_categories_count_CB_2017['GEOID10'] = OAK311_categories_count_CB_2017['GEOID10'].astype(str)

OAK311_categories_count_CB_2018 = pd.read_csv('../Data/311_Oakland/Oakland311_2018_pivotTable.csv')
OAK311_categories_count_CB_2018 = OAK311_categories_count_CB_2018.iloc[:,1:]
OAK311_categories_count_CB_2018['GEOID10'] = OAK311_categories_count_CB_2018['GEOID10'].astype(str)

OAK311_categories_count_CB_2019 = pd.read_csv('../Data/311_Oakland/Oakland311_2019_pivotTable.csv')
OAK311_categories_count_CB_2019 = OAK311_categories_count_CB_2019.iloc[:,1:]
OAK311_categories_count_CB_2019['GEOID10'] = OAK311_categories_count_CB_2019['GEOID10'].astype(str)

OAK311_categories_count_CB_2020 = pd.read_csv('../Data/311_Oakland/Oakland311_2020_pivotTable.csv')
OAK311_categories_count_CB_2020 = OAK311_categories_count_CB_2020.iloc[:,1:]
OAK311_categories_count_CB_2020['GEOID10'] = OAK311_categories_count_CB_2020['GEOID10'].astype(str)

OAK311_categories_count_CB_2021 = pd.read_csv('../Data/311_Oakland/Oakland311_2021_pivotTable.csv')
OAK311_categories_count_CB_2021 = OAK311_categories_count_CB_2021.iloc[:,1:]
OAK311_categories_count_CB_2021['GEOID10'] = OAK311_categories_count_CB_2021['GEOID10'].astype(str)

# %%
OAK311_categories_count_CB_2015
# Out:
#              GEOID10  BLDGMAINT  CUT_CLEAN  CW_DIT_GIS  DRAINAGE  ELECTRICAL  \
# 0     60014001001000          0          0           0         0           0
# 1     60014001001001          0          0           0         0           0
# 2     60014001001002          0          0           0         0           0
# 3     60014001001007          0          0           0         0           0
# 4     60014001001008          0          0           0         0           0
# ...              ...        ...        ...         ...       ...         ...
# 5341  60019832001051          1          0           0         0           0
# 5342  60019832001052          0          0           0         0           0
# 5343  60019832001053          0          0           0         0           0
# 5344  60019832001054          0          0           0         0           0
# 5345  60019832001055          0          0           0         1           0
#
# ...

# %%
MH_prevalence_CB_2015 = pd.read_csv('../Mental Health Prevalence/GEOID_MHprevalence_2015_CBlevel.csv')
MH_prevalence_CB_2016 = pd.read_csv('../Mental Health Prevalence/GEOID_MHprevalence_2016_CBlevel.csv')
MH_prevalence_CB_2017 = pd.read_csv('../Mental Health Prevalence/GEOID_MHprevalence_2017_CBlevel.csv')
MH_prevalence_CB_2018 = pd.read_csv('../Mental Health Prevalence/GEOID_MHprevalence_2018_CBlevel.csv')
MH_prevalence_CB_2019 = pd.read_csv('../Mental Health Prevalence/GEOID_MHprevalence_2019_CBlevel.csv')
MH_prevalence_CB_2020 = pd.read_csv('../Mental Health Prevalence/GEOID_MHprevalence_2020_CBlevel.csv')
MH_prevalence_CB_2021 = pd.read_csv('../Mental Health Prevalence/GEOID_MHprevalence_2021_CBlevel.csv')

# %%
# import matplotlib.pyplot as plt
# plt.hist(MH_prevalence_CB_2021['MH_prevalence'])
# plt.show() 
MH_prevalence_CB_2015_clean = MH_prevalence_CB_2015
MH_prevalence_CB_2015_clean['CB_GEOID'] = MH_prevalence_CB_2015_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[1:])#.astype(np.int32)
MH_prevalence_CB_2015_clean
MH_prevalence_CB_2015_clean['County_ID'] = MH_prevalence_CB_2015_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[:5])
MH_prevalence_CB_2015_clean['CT_ID'] = MH_prevalence_CB_2015_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[:11])
MH_prevalence_CB_2015_clean
# Out:
#                          GEO_ID  weighted_risk  Population  MH_prevalence  \
# 0      1000000US060014001001007       7.378503          95       0.077668
# 1      1000000US060014001001008       1.310187          20       0.065509
# 2      1000000US060014001001011       0.731250          12       0.060937
# 3      1000000US060014001001013       0.062124           1       0.062124
# 4      1000000US060014001001014       1.229433          18       0.068302
# ...                         ...            ...         ...            ...
# 14077  1000000US060019832001050       1.798899          18       0.099939
# 14078  1000000US060019832001052       2.731405          33       0.082770
# 14079  1000000US060019832001053       6.022247          60       0.100371
# 14080  1000000US060019832001054      16.167068         167       0.096809
# 14081  1000000US060019832001055       0.116126           1       0.116126
#
#              CB_GEOID County_ID        CT_ID
# ...

# %%
MH_prevalence_CB_2015_clean = MH_prevalence_CB_2015
MH_prevalence_CB_2015_clean['CB_GEOID'] = MH_prevalence_CB_2015_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[1:])#.astype(np.int32)
MH_prevalence_CB_2015_clean['County_ID'] = MH_prevalence_CB_2015_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[:5])
MH_prevalence_CB_2015_clean['CT_ID'] = MH_prevalence_CB_2015_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[:11])

MH_prevalence_CB_2016_clean = MH_prevalence_CB_2016
MH_prevalence_CB_2016_clean['CB_GEOID'] = MH_prevalence_CB_2016_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[1:])#.astype(np.int32)
MH_prevalence_CB_2016_clean['County_ID'] = MH_prevalence_CB_2016_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[:5])
MH_prevalence_CB_2016_clean['CT_ID'] = MH_prevalence_CB_2016_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[:11])

MH_prevalence_CB_2017_clean = MH_prevalence_CB_2017
MH_prevalence_CB_2017_clean['CB_GEOID'] = MH_prevalence_CB_2017_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[1:])#.astype(np.int32)
MH_prevalence_CB_2017_clean['County_ID'] = MH_prevalence_CB_2017_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[:5])
MH_prevalence_CB_2017_clean['CT_ID'] = MH_prevalence_CB_2017_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[:11])

MH_prevalence_CB_2018_clean = MH_prevalence_CB_2018
MH_prevalence_CB_2018_clean['CB_GEOID'] = MH_prevalence_CB_2018_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[1:])#.astype(np.int32)
MH_prevalence_CB_2018_clean['County_ID'] = MH_prevalence_CB_2018_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[:5])
MH_prevalence_CB_2018_clean['CT_ID'] = MH_prevalence_CB_2018_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[:11])

MH_prevalence_CB_2019_clean = MH_prevalence_CB_2019
MH_prevalence_CB_2019_clean['CB_GEOID'] = MH_prevalence_CB_2019_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[1:])#.astype(np.int32)
MH_prevalence_CB_2019_clean['County_ID'] = MH_prevalence_CB_2019_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[:5])
MH_prevalence_CB_2019_clean['CT_ID'] = MH_prevalence_CB_2019_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[:11])

MH_prevalence_CB_2020_clean = MH_prevalence_CB_2020
MH_prevalence_CB_2020_clean['CB_GEOID'] = MH_prevalence_CB_2020_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[1:])#.astype(np.int32)
MH_prevalence_CB_2020_clean['County_ID'] = MH_prevalence_CB_2020_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[:5])
MH_prevalence_CB_2020_clean['CT_ID'] = MH_prevalence_CB_2020_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[:11])

MH_prevalence_CB_2021_clean = MH_prevalence_CB_2021
MH_prevalence_CB_2021_clean['CB_GEOID'] = MH_prevalence_CB_2021_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[1:])#.astype(np.int32)
MH_prevalence_CB_2021_clean['County_ID'] = MH_prevalence_CB_2021_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[:5])
MH_prevalence_CB_2021_clean['CT_ID'] = MH_prevalence_CB_2021_clean['GEO_ID'].apply(lambda x:x.split('US')[1].strip()[:11])

# %%
# OAK311_categories_count_CB_2021 # 2010年数据显示只有6319个census blocks

# %%
# MH_prevalence_CB_2021#['CB_GEOID'].value_counts()# 342 census tract

# %%
# test
# MH_prevalence_CB_2021[MH_prevalence_CB_2021['CB_GEOID'] == '60014001001007']

# %%
# test
# OAK311_categories_count_CB_2021[OAK311_categories_count_CB_2021['GEOID10'] == '60014001001007']

# %%
 MH_prevalence_CB_2015_clean
# Out:
#                          GEO_ID  weighted_risk  Population  MH_prevalence  \
# 0      1000000US060014001001007       7.378503          95       0.077668
# 1      1000000US060014001001008       1.310187          20       0.065509
# 2      1000000US060014001001011       0.731250          12       0.060937
# 3      1000000US060014001001013       0.062124           1       0.062124
# 4      1000000US060014001001014       1.229433          18       0.068302
# ...                         ...            ...         ...            ...
# 14077  1000000US060019832001050       1.798899          18       0.099939
# 14078  1000000US060019832001052       2.731405          33       0.082770
# 14079  1000000US060019832001053       6.022247          60       0.100371
# 14080  1000000US060019832001054      16.167068         167       0.096809
# 14081  1000000US060019832001055       0.116126           1       0.116126
#
#              CB_GEOID County_ID        CT_ID
# ...

# %%
# left merge 用于转换成shapefile：
data_2015_ready_for_OLS = pd.merge(\
    OAK311_categories_count_CB_2015, MH_prevalence_CB_2015_clean, \
    left_on = 'GEOID10', right_on = 'CB_GEOID', how = 'left')
#data_2015_ready_for_OLS.to_csv('../data_for_OLS/data_2015_LeftMerge_ready_for_OLS.csv')

data_2016_ready_for_OLS = pd.merge(\
    OAK311_categories_count_CB_2016, MH_prevalence_CB_2016_clean, \
    left_on = 'GEOID10', right_on = 'CB_GEOID', how = 'left')
#data_2016_ready_for_OLS.to_csv('../data_for_OLS/data_2016_LeftMerge_ready_for_OLS.csv')

data_2017_ready_for_OLS = pd.merge(\
    OAK311_categories_count_CB_2017, MH_prevalence_CB_2017_clean, \
    left_on = 'GEOID10', right_on = 'CB_GEOID', how = 'left')
#data_2017_ready_for_OLS.to_csv('../data_for_OLS/data_2017_LeftMerge_ready_for_OLS.csv')

data_2018_ready_for_OLS = pd.merge(\
    OAK311_categories_count_CB_2018, MH_prevalence_CB_2018_clean, \
    left_on = 'GEOID10', right_on = 'CB_GEOID', how = 'left')
#data_2018_ready_for_OLS.to_csv('../data_for_OLS/data_2018_LeftMerge_ready_for_OLS.csv')

data_2019_ready_for_OLS = pd.merge(\
    OAK311_categories_count_CB_2019, MH_prevalence_CB_2019_clean, \
    left_on = 'GEOID10', right_on = 'CB_GEOID', how = 'left')
#data_2019_ready_for_OLS.to_csv('../data_for_OLS/data_2019_LeftMerge_ready_for_OLS.csv')

data_2020_ready_for_OLS = pd.merge(\
    OAK311_categories_count_CB_2020, MH_prevalence_CB_2020_clean, \
    left_on = 'GEOID10', right_on = 'CB_GEOID', how = 'left')
#data_2020_ready_for_OLS.to_csv('../data_for_OLS/data_2020_LeftMerge_ready_for_OLS.csv')

data_2021_ready_for_OLS = pd.merge(\
    OAK311_categories_count_CB_2021, MH_prevalence_CB_2021_clean, \
    left_on = 'GEOID10', right_on = 'CB_GEOID', how = 'left')
#data_2021_ready_for_OLS.to_csv('../data_for_OLS/data_2021_LeftMerge_ready_for_OLS.csv')

# %%
data_2021_ready_for_OLS
# Out:
#              GEOID10  ABANDONED AUTO  BLDGMAINT  CUT_CLEAN  CW_DIT_GIS  \
# 0     60014001001000               0          0          0           0
# 1     60014001001002               0          0          0           0
# 2     60014001001007               0          0          0           0
# 3     60014001001008               0          0          0           0
# 4     60014001001011               0          0          0           0
# ...              ...             ...        ...        ...         ...
# 5581  60019832001051               0          1          0           0
# 5582  60019832001052               0          0          0           0
# 5583  60019832001053               0          0          0           0
# 5584  60019832001054               0          0          0           0
# 5585  60019832001055               0          0          0           0
#
#       DRAINAGE  ELECTRICAL  ENVIRON_ENF  FACILITIES  FIRE  ...  sum_count  \
# ...

# %%
# 311没有空值：
# data_2021_ready_for_OLS[data_2021_ready_for_OLS['sum_count'].isna()]

# %%
# data_2021_ready_for_OLS[data_2021_ready_for_OLS['GEOID10'] == '60014001001007']

# %%
# data_2015_InnerMerge_ready_for_OLS = pd.merge(\
#     OAK311_categories_count_CB_2015, MH_prevalence_CB_2015, \
#     left_on = 'GEOID10', right_on = 'CB_GEOID', how = 'inner')
# data_2015_InnerMerge_ready_for_OLS.to_csv('../data_for_OLS/data_2015_InnerMerge_ready_for_OLS.csv')

# data_2016_InnerMerge_ready_for_OLS = pd.merge(\
#     OAK311_categories_count_CB_2016, MH_prevalence_CB_2016, \
#     left_on = 'GEOID10', right_on = 'CB_GEOID', how = 'inner')
# data_2016_InnerMerge_ready_for_OLS.to_csv('../data_for_OLS/data_2016_InnerMerge_ready_for_OLS.csv')

# data_2017_InnerMerge_ready_for_OLS = pd.merge(\
#     OAK311_categories_count_CB_2017, MH_prevalence_CB_2017, \
#     left_on = 'GEOID10', right_on = 'CB_GEOID', how = 'inner')
# data_2017_InnerMerge_ready_for_OLS.to_csv('../data_for_OLS/data_2017_InnerMerge_ready_for_OLS.csv')

# data_2018_InnerMerge_ready_for_OLS = pd.merge(\
#     OAK311_categories_count_CB_2018, MH_prevalence_CB_2018, \
#     left_on = 'GEOID10', right_on = 'CB_GEOID', how = 'inner')
# data_2018_InnerMerge_ready_for_OLS.to_csv('../data_for_OLS/data_2018_InnerMerge_ready_for_OLS.csv')

# data_2019_InnerMerge_ready_for_OLS = pd.merge(\
#     OAK311_categories_count_CB_2019, MH_prevalence_CB_2019, \
#     left_on = 'GEOID10', right_on = 'CB_GEOID', how = 'inner')
# data_2019_InnerMerge_ready_for_OLS.to_csv('../data_for_OLS/data_2019_InnerMerge_ready_for_OLS.csv')

# data_2020_InnerMerge_ready_for_OLS = pd.merge(\
#     OAK311_categories_count_CB_2020, MH_prevalence_CB_2020, \
#     left_on = 'GEOID10', right_on = 'CB_GEOID', how = 'inner')
# data_2020_InnerMerge_ready_for_OLS.to_csv('../data_for_OLS/data_2020_InnerMerge_ready_for_OLS.csv')

# data_2021_InnerMerge_ready_for_OLS = pd.merge(\
#     OAK311_categories_count_CB_2021, MH_prevalence_CB_2021, \
#     left_on = 'GEOID10', right_on = 'CB_GEOID', how = 'inner')
# data_2021_InnerMerge_ready_for_OLS.to_csv('../data_for_OLS/data_2021_InnerMerge_ready_for_OLS.csv')

# %%
# MH_prevalence_CB_2015['MH_prevalence'].value_counts(dropna = False)

# %%
data_2021_ready_for_OLS
# Out:
#              GEOID10  ABANDONED AUTO  BLDGMAINT  CUT_CLEAN  CW_DIT_GIS  \
# 0     60014001001000               0          0          0           0
# 1     60014001001002               0          0          0           0
# 2     60014001001007               0          0          0           0
# 3     60014001001008               0          0          0           0
# 4     60014001001011               0          0          0           0
# ...              ...             ...        ...        ...         ...
# 5581  60019832001051               0          1          0           0
# 5582  60019832001052               0          0          0           0
# 5583  60019832001053               0          0          0           0
# 5584  60019832001054               0          0          0           0
# 5585  60019832001055               0          0          0           0
#
#       DRAINAGE  ELECTRICAL  ENVIRON_ENF  FACILITIES  FIRE  ...  sum_count  \
# ...

# %%
data_2015_ready_for_OLS.columns[1:-9]
# Out:
# Index(['BLDGMAINT', 'CUT_CLEAN', 'CW_DIT_GIS', 'DRAINAGE', 'ELECTRICAL',
#        'FIRE', 'GRAFFITI', 'HE_CLEAN', 'ILLDUMP', 'KOCB', 'METER_REPAIR',
#        'OTHER', 'PARKING', 'PARKS', 'RECYCLING', 'ROW', 'ROW_INSPECTORS',
#        'ROW_STREETSW', 'SEWERS', 'STREETSW', 'SURVEY', 'TRAFFIC',
#        'TRAFFIC_ENGIN', 'TREES', 'WATERSHED', 'sum_count'],
#       dtype='object')

# %% [markdown]
# # 将数据转成shapefile

# %%
# columns_to_divide_2015 = data_2015_ready_for_OLS.columns[1:-10]
# for col in columns_to_divide_2015:
#     data_2015_ready_for_OLS[col + '_perc'] = data_2015_ready_for_OLS[col] / data_2015_ready_for_OLS['Population']

# columns_to_divide_2016 = data_2016_ready_for_OLS.columns[1:-10]
# for col in columns_to_divide_2016:
#     data_2016_ready_for_OLS[col + '_perc'] = data_2016_ready_for_OLS[col] / data_2016_ready_for_OLS['Population']

# columns_to_divide_2017 = data_2017_ready_for_OLS.columns[1:-10]
# for col in columns_to_divide_2017:
#     data_2017_ready_for_OLS[col + '_perc'] = data_2017_ready_for_OLS[col] / data_2017_ready_for_OLS['Population']

# columns_to_divide_2018 = data_2018_ready_for_OLS.columns[1:-10]
# for col in columns_to_divide_2018:
#     data_2018_ready_for_OLS[col + '_perc'] = data_2018_ready_for_OLS[col] / data_2018_ready_for_OLS['Population']

# columns_to_divide_2019 = data_2019_ready_for_OLS.columns[1:-10]
# for col in columns_to_divide_2019:
#     data_2019_ready_for_OLS[col + '_perc'] = data_2019_ready_for_OLS[col] / data_2019_ready_for_OLS['Population']

# columns_to_divide_2020 = data_2020_ready_for_OLS.columns[1:-10]
# for col in columns_to_divide_2020:
#     data_2020_ready_for_OLS[col + '_perc'] = data_2020_ready_for_OLS[col] / data_2020_ready_for_OLS['Population']

# columns_to_divide_2021 = data_2021_ready_for_OLS.columns[1:-10]
# for col in columns_to_divide_2021:
#     data_2021_ready_for_OLS[col + '_perc'] = data_2021_ready_for_OLS[col] / data_2021_ready_for_OLS['Population']

# %%
data_2021_ready_for_OLS.columns
# Out:
# Index(['GEOID10', 'ABANDONED AUTO', 'BLDGMAINT', 'CUT_CLEAN', 'CW_DIT_GIS',
#        'DRAINAGE', 'ELECTRICAL', 'ENVIRON_ENF', 'FACILITIES', 'FIRE',
#        'GRAFFITI', 'HE_CLEAN', 'HOMELESS EMT', 'ILLDUMP', 'KOCB',
#        'METER_REPAIR', 'OTHER', 'PARKING', 'PARKS', 'POLICE', 'RECYCLING',
#        'ROW_INSPECTORS', 'ROW_STREETSW', 'SEWERS', 'STREETSW', 'SURVEY',
#        'TRAFFIC', 'TRAFFIC_ENGIN', 'TREES', 'WATERSHED', 'sum_count', 'CBG_ID',
#        'CBG_pop', 'GEO_ID', 'weighted_risk', 'Population', 'MH_prevalence',
#        'CB_GEOID', 'County_ID', 'CT_ID', 'ABANDONED AUTO_perc',
#        'BLDGMAINT_perc', 'CUT_CLEAN_perc', 'CW_DIT_GIS_perc', 'DRAINAGE_perc',
#        'ELECTRICAL_perc', 'ENVIRON_ENF_perc', 'FACILITIES_perc', 'FIRE_perc',
#        'GRAFFITI_perc', 'HE_CLEAN_perc', 'HOMELESS EMT_perc', 'ILLDUMP_perc',
#        'KOCB_perc', 'METER_REPAIR_perc', 'OTHER_perc', 'PARKING_perc',
#        'PARKS_perc', 'POLICE_perc', 'RECYCLING_perc', 'ROW_INSPECTORS_perc',
# ...

# %%
import geopandas as gpd
oakland_CB_shapefile = gpd.read_file('../Data/311_Oakland/Oakland_CB_2010_Project.shp')
oakland_CB_shapefile['GEOID10'] = oakland_CB_shapefile['GEOID10'].apply(lambda x:x[1:])

# %%
# oakland_CB_shapefile
# fig, ax = plt.subplots(figsize=(10, 10))
# oakland_CB_shapefile.plot(ax=ax, edgecolor='black')
# ax.set_title('Shapefile Map')
# plt.show()

# %%
#data_2021_ready_for_OLS oakland_CB_shapefile
# merged_gdf = oakland_CB_shapefile.merge(data_2021_ready_for_OLS, on='GEOID10')
merged_gdf_2021 = pd.merge(oakland_CB_shapefile, data_2021_ready_for_OLS, on = 'GEOID10', how = 'left')
merged_gdf_2021 = gpd.GeoDataFrame(merged_gdf_2021, geometry='geometry')

merged_gdf_2020 = pd.merge(oakland_CB_shapefile, data_2020_ready_for_OLS, on = 'GEOID10', how = 'left')
merged_gdf_2020 = gpd.GeoDataFrame(merged_gdf_2020, geometry='geometry')

merged_gdf_2019 = pd.merge(oakland_CB_shapefile, data_2019_ready_for_OLS, on = 'GEOID10', how = 'left')
merged_gdf_2019 = gpd.GeoDataFrame(merged_gdf_2019, geometry='geometry')

merged_gdf_2018 = pd.merge(oakland_CB_shapefile, data_2018_ready_for_OLS, on = 'GEOID10', how = 'left')
merged_gdf_2018 = gpd.GeoDataFrame(merged_gdf_2018, geometry='geometry')

merged_gdf_2017 = pd.merge(oakland_CB_shapefile, data_2017_ready_for_OLS, on = 'GEOID10', how = 'left')
merged_gdf_2017 = gpd.GeoDataFrame(merged_gdf_2017, geometry='geometry')

merged_gdf_2016 = pd.merge(oakland_CB_shapefile, data_2016_ready_for_OLS, on = 'GEOID10', how = 'left')
merged_gdf_2016 = gpd.GeoDataFrame(merged_gdf_2016, geometry='geometry')

merged_gdf_2015 = pd.merge(oakland_CB_shapefile, data_2015_ready_for_OLS, on = 'GEOID10', how = 'left')
merged_gdf_2015 = gpd.GeoDataFrame(merged_gdf_2015, geometry='geometry')

# %%
merged_gdf_2015.columns
# Out:
# Index(['STATEFP10', 'COUNTYFP10', 'TRACTCE10', 'BLOCKCE10', 'GEOID10',
#        'NAME10', 'MTFCC10', 'UR10', 'UACE10', 'UATYP10', 'FUNCSTAT10',
#        'ALAND10', 'AWATER10', 'INTPTLAT10', 'INTPTLON10', 'Shape_Leng',
#        'Shape_Area', 'geometry', 'BLDGMAINT', 'CUT_CLEAN', 'CW_DIT_GIS',
#        'DRAINAGE', 'ELECTRICAL', 'FIRE', 'GRAFFITI', 'HE_CLEAN', 'ILLDUMP',
#        'KOCB', 'METER_REPAIR', 'OTHER', 'PARKING', 'PARKS', 'RECYCLING', 'ROW',
#        'ROW_INSPECTORS', 'ROW_STREETSW', 'SEWERS', 'STREETSW', 'SURVEY',
#        'TRAFFIC', 'TRAFFIC_ENGIN', 'TREES', 'WATERSHED', 'sum_count', 'CBG_ID',
#        'CBG_pop', 'GEO_ID', 'weighted_risk', 'Population', 'MH_prevalence',
#        'CB_GEOID', 'County_ID', 'CT_ID'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
# Plotting the distribution of 'weighted_risk' on the map
# fig, ax = plt.subplots(1, 1, figsize=(12, 8))
# merged_gdf_2021.plot(column='MH_prevalence', ax=ax, legend=True, cmap='OrRd', edgecolor='k', linewidth=0.1)
# ax.set_title('Distribution of Weighted Risk')
# plt.show()

# merged_gdf_2021['quintile'] = pd.qcut(merged_gdf_2021['MH_prevalence'], 5, labels=False)
# # Plotting the distribution of 'weighted_risk' on the map
# fig, ax = plt.subplots(1, 1, figsize=(12, 8))
# merged_gdf_2021.plot(column='quintile', ax=ax, legend=True, cmap='OrRd', edgecolor='k', linewidth=0.1)
# ax.set_title('Distribution of Weighted Risk by Quintile')
# plt.show()

fig, ax = plt.subplots(1, 1, figsize=(12, 8))

# 使用 'viridis' 颜色映射方案绘制地理数据，这个颜色映射类似于 R 的默认配色方案
merged_gdf_2021_dropna = merged_gdf_2021.dropna(subset=['METER_REPAIR',"sum_count"])
merged_gdf_2021_dropna.plot(column='MH_prevalence', ax=ax, legend=True, cmap='viridis', edgecolor='k', linewidth=0.1)

# 设置图标题
ax.set_title('Values')

# 显示图表
plt.show()

# %%
merged_gdf_2021_dropna
# Out:
#      STATEFP10 COUNTYFP10 TRACTCE10 BLOCKCE10         GEOID10      NAME10  \
# 0           06        001    410000      2024  60014100002024  Block 2024
# 1           06        001    407300      2017  60014073002017  Block 2017
# 2           06        001    408100      2011  60014081002011  Block 2011
# 3           06        001    401000      2002  60014010002002  Block 2002
# 5           06        001    405301      2002  60014053012002  Block 2002
# ...        ...        ...       ...       ...             ...         ...
# 6311        06        001    406601      1009  60014066011009  Block 1009
# 6313        06        001    410200      2007  60014102002007  Block 2007
# 6314        06        001    409900      1054  60014099001054  Block 1054
# 6315        06        001    406500      2005  60014065002005  Block 2005
# 6317        06        001    403400      1018  60014034001018  Block 1018
#
#      MTFCC10 UR10 UACE10 UATYP10  ... sum_count        CBG_ID  CBG_pop  \
# ...

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
merged_gdf_2021.plot(column='MH_prevalence', ax=ax, legend=True, cmap='OrRd', edgecolor='k', linewidth=0.1)
ax.set_title('Distribution of Weighted Risk')
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
merged_gdf_2015[merged_gdf_2015['MH_prevalence'].isna()].plot(ax=ax, color='red', edgecolor='k', linewidth=0.1)
ax.set_title('Map of Areas with NaN Weighted Risk')
plt.show()

# %%
merged_gdf_2015.columns
# Out:
# Index(['STATEFP10', 'COUNTYFP10', 'TRACTCE10', 'BLOCKCE10', 'GEOID10',
#        'NAME10', 'MTFCC10', 'UR10', 'UACE10', 'UATYP10', 'FUNCSTAT10',
#        'ALAND10', 'AWATER10', 'INTPTLAT10', 'INTPTLON10', 'Shape_Leng',
#        'Shape_Area', 'geometry', 'BLDGMAINT', 'CUT_CLEAN', 'CW_DIT_GIS',
#        'DRAINAGE', 'ELECTRICAL', 'FIRE', 'GRAFFITI', 'HE_CLEAN', 'ILLDUMP',
#        'KOCB', 'METER_REPAIR', 'OTHER', 'PARKING', 'PARKS', 'RECYCLING', 'ROW',
#        'ROW_INSPECTORS', 'ROW_STREETSW', 'SEWERS', 'STREETSW', 'SURVEY',
#        'TRAFFIC', 'TRAFFIC_ENGIN', 'TREES', 'WATERSHED', 'sum_count', 'CBG_ID',
#        'CBG_pop', 'GEO_ID', 'weighted_risk', 'Population', 'MH_prevalence',
#        'CB_GEOID', 'County_ID', 'CT_ID'],
#       dtype='object')

# %%
merged_gdfs = [merged_gdf_2015, merged_gdf_2016, merged_gdf_2017, merged_gdf_2018, merged_gdf_2019, merged_gdf_2020, merged_gdf_2021]
for gdf in merged_gdfs:
    gdf = gdf.fillna(0)

# %%
merged_gdf_2015.to_file('../Data/311_Oakland/data_2015_ready_for_spatialModel.shp')
merged_gdf_2016.to_file('../Data/311_Oakland/data_2016_ready_for_spatialModel.shp')
merged_gdf_2017.to_file('../Data/311_Oakland/data_2017_ready_for_spatialModel.shp')
merged_gdf_2018.to_file('../Data/311_Oakland/data_2018_ready_for_spatialModel.shp')
merged_gdf_2019.to_file('../Data/311_Oakland/data_2019_ready_for_spatialModel.shp')
merged_gdf_2020.to_file('../Data/311_Oakland/data_2020_ready_for_spatialModel.shp')
merged_gdf_2021.to_file('../Data/311_Oakland/data_2021_ready_for_spatialModel.shp')
# Out:
# C:\Users\jduan\AppData\Local\Temp\ipykernel_5320\1817221219.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   merged_gdf_2015.to_file('../Data/311_Oakland/data_2015_ready_for_spatialModel.shp')
# C:\Users\jduan\AppData\Local\Temp\ipykernel_5320\1817221219.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   merged_gdf_2016.to_file('../Data/311_Oakland/data_2016_ready_for_spatialModel.shp')
# C:\Users\jduan\AppData\Local\Temp\ipykernel_5320\1817221219.py:3: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   merged_gdf_2017.to_file('../Data/311_Oakland/data_2017_ready_for_spatialModel.shp')
# C:\Users\jduan\AppData\Local\Temp\ipykernel_5320\1817221219.py:4: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# ...

# %%
merged_gdf_2018
# Out:
#      STATEFP10 COUNTYFP10 TRACTCE10 BLOCKCE10         GEOID10      NAME10  \
# 0           06        001    410000      2024  60014100002024  Block 2024
# 1           06        001    407300      2017  60014073002017  Block 2017
# 2           06        001    408100      2011  60014081002011  Block 2011
# 3           06        001    401000      2002  60014010002002  Block 2002
# 4           06        001    406100      1005  60014061001005  Block 1005
# ...        ...        ...       ...       ...             ...         ...
# 6314        06        001    409900      1054  60014099001054  Block 1054
# 6315        06        001    406500      2005  60014065002005  Block 2005
# 6316        06        001    406500      2012  60014065002012  Block 2012
# 6317        06        001    403400      1018  60014034001018  Block 1018
# 6318        06        001    408200      3009  60014082003009  Block 3009
#
#      MTFCC10 UR10 UACE10 UATYP10  ... sum_count        CBG_ID  CBG_pop  \
# ...

# %% [markdown]
# ### R code里进行所有的spatial modeling
